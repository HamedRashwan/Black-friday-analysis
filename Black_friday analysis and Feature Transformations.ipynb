# %% [markdown]
# # Task 8 (Feature Transformations #1)
# Using black_friday.csv and apply what you learned in data preprocessing lectures.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import datasist as ds

# %matplotlib inline
sns.set(rc={'figure.figsize': [10, 10]}, font_scale=1.2)

# %%
df = pd.read_csv(r'D:\COURSES\AI\Epsilon Ai\Session 25\Assigment\datasets\black_friday.csv')
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# 2                               2               0                  12
# 3                               2               0                  12
# 4                              4+               0                   8
# ...                           ...             ...                 ...
# 550063                          1               1                  20
# 550064                          3               0                  20
# 550065                         4+               1                  20
# 550066                          2               0                  20
# 550067                         4+               1                  20
#
#         Product_Category_2  Product_Category_3  Purchase
# 0                      NaN                 NaN      8370
# 1                      6.0                14.0     15200
# 2                      NaN                 NaN      1422
# 3                     14.0                 NaN      1057
# 4                      NaN                 NaN      7969
# ...                    ...                 ...       ...
# 550063                 NaN                 NaN       368
# 550064                 NaN                 NaN       371
# 550065                 NaN                 NaN       137
# 550066                 NaN                 NaN       365
# 550067                 NaN                 NaN       490
#
# [550068 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 50.4+ MB

# %%
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       376430.000000       166821.000000  550068.000000
# mean             9.842329           12.668243    9263.968713
# std              5.086590            4.125338    5023.065394
# min              2.000000            3.000000      12.000000
# 25%              5.000000            9.000000    5823.000000
# 50%              9.000000           14.000000    8047.000000
# 75%             15.000000           16.000000   12054.000000
# max             18.000000           18.000000   23961.000000

# %%
df['User_ID'].value_counts()
# Out:
# User_ID
# 1001680    1026
# 1004277     979
# 1001941     898
# 1001181     862
# 1000889     823
#            ...
# 1002690       7
# 1002111       7
# 1005810       7
# 1004991       7
# 1000708       6
# Name: count, Length: 5891, dtype: int64

# %%
len(df['User_ID'].value_counts())
# Out:
# 5891

# %%
df['Product_ID'].value_counts()
# Out:
# Product_ID
# P00265242    1880
# P00025442    1615
# P00110742    1612
# P00112142    1562
# P00057642    1470
#              ...
# P00314842       1
# P00298842       1
# P00231642       1
# P00204442       1
# P00066342       1
# Name: count, Length: 3631, dtype: int64

# %%
len(df['Product_ID'].value_counts())
# Out:
# 3631

# %%
df['Age'].value_counts()
# Out:
# Age
# 26-35    219587
# 36-45    110013
# 18-25     99660
# 46-50     45701
# 51-55     38501
# 55+       21504
# 0-17      15102
# Name: count, dtype: int64

# %%
df['City_Category'].value_counts()
# Out:
# City_Category
# B    231173
# C    171175
# A    147720
# Name: count, dtype: int64

# %%
df['Marital_Status'].value_counts()
# Out:
# Marital_Status
# 0    324731
# 1    225337
# Name: count, dtype: int64

# %%
df['Occupation'].value_counts()
# Out:
# Occupation
# 4     72308
# 0     69638
# 7     59133
# 1     47426
# 17    40043
# 20    33562
# 12    31179
# 14    27309
# 2     26588
# 16    25371
# 6     20355
# 3     17650
# 10    12930
# 5     12177
# 15    12165
# 11    11586
# 19     8461
# 13     7728
# 18     6622
# 9      6291
# 8      1546
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# 2                 NaN                 NaN      1422
# 3                14.0                 NaN      1057
# 4                 NaN                 NaN      7969

# %%
sns.countplot(x='Gender', data=df, palette='viridis')
# Out:
# C:\Users\Hamed\AppData\Local\Temp\ipykernel_11284\277886450.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Gender', data=df, palette='viridis')
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x='Age', data=df, palette='viridis')
# Out:
# C:\Users\Hamed\AppData\Local\Temp\ipykernel_11284\1332442051.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Age', data=df, palette='viridis')
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x='Age', data=df, hue='Gender', palette='viridis')
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x='City_Category', data=df, palette='viridis')
# Out:
# C:\Users\Hamed\AppData\Local\Temp\ipykernel_11284\3958740327.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='City_Category', data=df, palette='viridis')
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(x='Marital_Status', data=df, palette='viridis')
# Out:
# C:\Users\Hamed\AppData\Local\Temp\ipykernel_11284\135929530.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Marital_Status', data=df, palette='viridis')
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
sns.countplot(x='Occupation', data=df, palette='viridis')
# Out:
# C:\Users\Hamed\AppData\Local\Temp\ipykernel_11284\15871027.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Occupation', data=df, palette='viridis')
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
sns.catplot(kind='count', y='Occupation', data=df, row='Age', palette='viridis')
# Out:
# C:\Users\Hamed\AppData\Local\Temp\ipykernel_11284\2879607214.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(kind='count', y='Occupation', data=df, row='Age', palette='viridis')

# %%
sns.countplot(x='Product_Category_1', data=df, palette='viridis')
# Out:
# C:\Users\Hamed\AppData\Local\Temp\ipykernel_11284\2519124388.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Product_Category_1', data=df, palette='viridis')
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
sns.boxplot(x='Age', y='Purchase', data=df, palette='rocket')
# Out:
# C:\Users\Hamed\AppData\Local\Temp\ipykernel_11284\2517860323.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Age', y='Purchase', data=df, palette='rocket')
# <Axes: xlabel='Age', ylabel='Purchase'>

# %%
sns.boxplot(x='Gender', y='Purchase', data=df, palette='rocket')
# Out:
# C:\Users\Hamed\AppData\Local\Temp\ipykernel_11284\3883498921.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Gender', y='Purchase', data=df, palette='rocket')
# <Axes: xlabel='Gender', ylabel='Purchase'>

# %%
sns.boxplot(x='City_Category', y='Purchase', data=df, palette='rocket')
# Out:
# C:\Users\Hamed\AppData\Local\Temp\ipykernel_11284\1506685371.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='City_Category', y='Purchase', data=df, palette='rocket')
# <Axes: xlabel='City_Category', ylabel='Purchase'>

# %%
sns.catplot(kind='box', x='Gender', y='Purchase', data=df, palette='viridis', row='Age', col='City_Category', hue='Marital_Status')

# %%
sns.barplot(x='Gender', y='Purchase', data=df, estimator=np.median)
# Out:
# <Axes: xlabel='Gender', ylabel='Purchase'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 50.4+ MB

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# 2                 NaN                 NaN      1422
# 3                14.0                 NaN      1057
# 4                 NaN                 NaN      7969

# %%
df['Product_Category_3'].value_counts()
# Out:
# Product_Category_3
# 16.0    32636
# 15.0    28013
# 14.0    18428
# 17.0    16702
# 5.0     16658
# 8.0     12562
# 9.0     11579
# 12.0     9246
# 13.0     5459
# 6.0      4890
# 18.0     4629
# 4.0      1875
# 11.0     1805
# 10.0     1726
# 3.0       613
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
df = df.drop(['User_ID', 'Product_ID', 'Product_Category_3'], axis=1)
df
# Out:
#        Gender    Age  Occupation City_Category Stay_In_Current_City_Years  \
# 0           F   0-17          10             A                          2
# 1           F   0-17          10             A                          2
# 2           F   0-17          10             A                          2
# 3           F   0-17          10             A                          2
# 4           M    55+          16             C                         4+
# ...       ...    ...         ...           ...                        ...
# 550063      M  51-55          13             B                          1
# 550064      F  26-35           1             C                          3
# 550065      F  26-35          15             B                         4+
# 550066      F    55+           1             C                          2
# 550067      F  46-50           0             B                         4+
#
#         Marital_Status  Product_Category_1  Product_Category_2  Purchase
# 0                    0                   3                 NaN      8370
# 1                    0                   1                 6.0     15200
# 2                    0                  12                 NaN      1422
# 3                    0                  12                14.0      1057
# 4                    0                   8                 NaN      7969
# ...                ...                 ...                 ...       ...
# 550063               1                  20                 NaN       368
# 550064               0                  20                 NaN       371
# 550065               1                  20                 NaN       137
# 550066               0                  20                 NaN       365
# 550067               1                  20                 NaN       490
#
# [550068 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Purchase                           0
# dtype: int64

# %%
df['Product_Category_2'].mode()[0]
# Out:
# 8.0

# %%
df['Product_Category_2'].fillna(df['Product_Category_2'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Purchase                      0
# dtype: int64

# %%
outliers_indices = ds.structdata.detect_outliers(df, 0, df.select_dtypes(include=['number']).columns)
df.drop(outliers_indices, inplace=True)

# %%
df = pd.get_dummies(df, columns=df.columns[:-1], drop_first=True)
df
# Out:
#         Purchase  Gender_M  Age_18-25  Age_26-35  Age_36-45  Age_46-50  \
# 0           8370     False      False      False      False      False
# 1          15200     False      False      False      False      False
# 2           1422     False      False      False      False      False
# 3           1057     False      False      False      False      False
# 4           7969      True      False      False      False      False
# ...          ...       ...        ...        ...        ...        ...
# 545910      9855      True      False       True      False      False
# 545911      1962      True      False       True      False      False
# 545912      7852      True      False       True      False      False
# 545913      7159      True      False       True      False      False
# 545914     11640      True      False       True      False      False
#
#         Age_51-55  Age_55+  Occupation_1  Occupation_2  ...  \
# 0           False    False         False         False  ...
# 1           False    False         False         False  ...
# 2           False    False         False         False  ...
# 3           False    False         False         False  ...
# 4           False     True         False         False  ...
# ...           ...      ...           ...           ...  ...
# 545910      False    False         False         False  ...
# 545911      False    False         False         False  ...
# 545912      False    False         False         False  ...
# 545913      False    False         False         False  ...
# 545914      False    False         False         False  ...
#
#         Product_Category_2_9.0  Product_Category_2_10.0  \
# 0                        False                    False
# 1                        False                    False
# 2                        False                    False
# 3                        False                    False
# 4                        False                    False
# ...                        ...                      ...
# 545910                   False                    False
# 545911                   False                    False
# 545912                   False                    False
# 545913                   False                    False
# 545914                   False                    False
#
#         Product_Category_2_11.0  Product_Category_2_12.0  \
# 0                         False                    False
# 1                         False                    False
# 2                         False                    False
# 3                         False                    False
# 4                         False                    False
# ...                         ...                      ...
# 545910                    False                    False
# 545911                    False                    False
# 545912                    False                    False
# 545913                    False                    False
# 545914                    False                    False
#
#         Product_Category_2_13.0  Product_Category_2_14.0  \
# 0                         False                    False
# 1                         False                    False
# 2                         False                    False
# 3                         False                     True
# 4                         False                    False
# ...                         ...                      ...
# 545910                    False                    False
# 545911                    False                    False
# 545912                    False                    False
# 545913                    False                    False
# 545914                    False                    False
#
#         Product_Category_2_15.0  Product_Category_2_16.0  \
# 0                         False                    False
# 1                         False                    False
# 2                         False                    False
# 3                         False                    False
# 4                         False                    False
# ...                         ...                      ...
# 545910                    False                    False
# 545911                    False                    False
# 545912                    False                    False
# 545913                    False                    False
# 545914                    False                    False
#
#         Product_Category_2_17.0  Product_Category_2_18.0
# 0                         False                    False
# 1                         False                    False
# 2                         False                    False
# 3                         False                    False
# 4                         False                    False
# ...                         ...                      ...
# 545910                    False                    False
# 545911                    False                    False
# 545912                    False                    False
# 545913                    False                    False
# 545914                    False                    False
#
# [543238 rows x 68 columns]

# %%
x = df.drop('Purchase', axis=1)
y = df['Purchase']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state=22)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

scaler.fit(x_train)
# Out:
# StandardScaler()

# %%
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)
